# %%
import json
import pandas as pd
import numpy as np

# %%
file_name = "../trip_advisor/tripadvisor_european_restaurants.csv"
import_csv = pd.read_csv(file_name)
# Out:
# c:\users\julia\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
euro_resto = pd.DataFrame(import_csv)

# %%
euro_resto.columns
# Out:
# Index(['restaurant_link', 'restaurant_name', 'original_location', 'country',
#        'region', 'province', 'city', 'address', 'latitude', 'longitude',
#        'claimed', 'awards', 'popularity_detailed', 'popularity_generic',
#        'top_tags', 'price_level', 'price_range', 'meals', 'cuisines',
#        'special_diets', 'features', 'vegetarian_friendly', 'vegan_options',
#        'gluten_free', 'original_open_hours', 'open_days_per_week',
#        'open_hours_per_week', 'working_shifts_per_week', 'avg_rating',
#        'total_reviews_count', 'default_language',
#        'reviews_count_in_default_language', 'excellent', 'very_good',
#        'average', 'poor', 'terrible', 'food', 'service', 'value', 'atmosphere',
#        'keywords'],
#       dtype='object')

# %%
# euro_resto_clean = euro_resto.drop(['original_location', 'claimed', 'keywords', 
#                               'atmosphere', 'awards', 'popularity_detailed', 
#                               'popularity_generic', 'top_tags', 'meals','special_diets', 'features', 
#                               'vegetarian_friendly', 
#                               'vegan_options','gluten_free', 'original_open_hours', 'open_days_per_week',
#                               'open_hours_per_week', 'working_shifts_per_week',
#                               'reviews_count_in_default_language', 'excellent', 'very_good',
#                              'average', 'poor', 'terrible', 'food', 'service', 'value', 'atmosphere',
#                              'keywords'], axis=1)

# %%
euro_resto_clean.head(150)
# Out:
#          restaurant_link             restaurant_name country  \
# 0    g10001637-d10002227                      Le 147  France
# 1    g10001637-d14975787            Le Saint Jouvent  France
# 2     g10002858-d4586832             Au Bout du Pont  France
# 3     g10002986-d3510044         Le Relais de Naiade  France
# 4     g10022428-d9767191        Relais Du MontSeigne  France
# ..                   ...                         ...     ...
# 145   g1006521-d10228842  Restaurant La Maison Bleue  France
# 146   g1006521-d10379499                La Mona Lisa  France
# 147   g1006521-d11741405      La Cabane De Massepain  France
# 148   g1006521-d11960581                   Pizza Hut  France
# 149   g1006521-d12182039                     O'Tacos  France
#
#                   region      province                      city  \
# 0     Nouvelle-Aquitaine  Haute-Vienne             Saint-Jouvent
# 1     Nouvelle-Aquitaine  Haute-Vienne             Saint-Jouvent
# 2    Centre-Val de Loire         Berry                Rivarennes
# 3     Nouvelle-Aquitaine       Correze                   Lacelle
# 4              Occitanie       Aveyron  Saint-Laurent-de-Levezou
# ..                   ...           ...                       ...
# 145        Ile-de-France    Val-d'Oise              Franconville
# 146        Ile-de-France    Val-d'Oise              Franconville
# 147        Ile-de-France    Val-d'Oise              Franconville
# 148        Ile-de-France    Val-d'Oise              Franconville
# 149        Ile-de-France    Val-d'Oise              Franconville
#
#                                                address   latitude  longitude  \
# 0          10 Maison Neuve, 87510 Saint-Jouvent France  45.961674   1.169131
# 1     16 Place de l Eglise, 87510 Saint-Jouvent France  45.957040   1.205480
# 2             2 rue des Dames, 36800 Rivarennes France  46.635895   1.386133
# 3    9 avenue Porte de la Correze 19170, 19170 Lace...  45.642610   1.824460
# 4    route du Montseigne, 12620 Saint-Laurent-de-Le...  44.208860   2.960470
# ..                                                 ...        ...        ...
# 145          3 rue de Paris, 95130 Franconville France  48.980000   2.235576
# 146  11 boulevard Maurice Berteaux, 95130 Franconvi...  48.985000   2.227500
# 147  362 rue du General Leclerc 362 Rue du General ...  48.990726   2.206646
# 148         41 rue de Paris, 95130 Franconville France  48.981506   2.232147
# 149         41 rue de Paris, 95130 Franconville France  48.981900   2.231930
#
#     price_level price_range              cuisines  avg_rating  \
# 0             €         NaN                French         4.0
# 1             €         NaN                   NaN         4.0
# 2             €         NaN      French, European         5.0
# 3             €         NaN                French         4.0
# 4        €€-€€€         NaN                French         4.5
# ..          ...         ...                   ...         ...
# 145           €         NaN  Portuguese, European         4.0
# 146      €€-€€€         NaN               Italian         4.0
# 147           €       €4-€9     French, Fast food         5.0
# 148      €€-€€€         NaN        Pizza, Italian         3.0
# 149         NaN         NaN             Fast food         2.5
#
#      total_reviews_count default_language
# 0                   36.0          English
# 1                    5.0    All languages
# 2                   13.0          English
# 3                   34.0          English
# 4                   11.0    All languages
# ..                   ...              ...
# 145                 25.0    All languages
# 146                 51.0    All languages
# 147                 70.0    All languages
# 148                 19.0    All languages
# 149                 10.0    All languages
#
# [150 rows x 15 columns]

# %%
euro_resto_clean.count()
# Out:
# restaurant_link        1083397
# restaurant_name        1083397
# country                1083397
# region                 1033074
# province                742765
# city                    682712
# address                1083397
# latitude               1067607
# longitude              1067607
# price_level             806192
# price_range             304327
# cuisines                914294
# avg_rating              986761
# total_reviews_count    1031162
# default_language        988204
# dtype: int64

# %%
null_cost = euro_resto_clean[euro_resto_clean.notnull()].count()
null_cost
# Out:
# restaurant_link        1083397
# restaurant_name        1083397
# country                1083397
# region                 1033074
# province                742765
# city                    682712
# address                1083397
# latitude               1067607
# longitude              1067607
# price_level             806192
# price_range             304327
# cuisines                914294
# avg_rating              986761
# total_reviews_count    1031162
# default_language        988204
# dtype: int64

# %%
britain_df = euro_resto_clean.loc[(euro_resto_clean['country'] == "England")| 
                                    (euro_resto_clean['country'] == "Ireland")|
                                   (euro_resto_clean['country'] == "Scotland")|
                                    (euro_resto_clean['country'] == "Wales")]
britain_df
# Out:
#             restaurant_link                    restaurant_name  country  \
# 478379   g10021931-d3222824                         Cafe Mylor  England
# 478380  g10029240-d10081265                             Subway  England
# 478381  g10029240-d10081305                         The Bakery  England
# 478382  g10029240-d11841828                   Basmati tandoori  England
# 478383  g10029240-d13010016                         China Chef  England
# ...                     ...                                ...      ...
# 886004     g983265-d1520699          Motte & Bailey Restaurant  Ireland
# 886005     g983265-d8155300                       Frank's Cafe  Ireland
# 886006     g983265-d8394067           Supermac's & Papa John's  Ireland
# 886007     g983265-d8448630  Tuar Ard Coffee Shop & Restaurant  Ireland
# 886008     g983265-d9766749                      P. Egan's Bar  Ireland
#
#                       region          province              city  \
# 478379              Cornwall          Falmouth  Mylor Churchtown
# 478380                Surrey               NaN           Byfleet
# 478381                Surrey               NaN           Byfleet
# 478382                Surrey               NaN           Byfleet
# 478383                Surrey               NaN           Byfleet
# ...                      ...               ...               ...
# 886004  Province of Leinster  County Westmeath             Moate
# 886005  Province of Leinster  County Westmeath             Moate
# 886006  Province of Leinster  County Westmeath             Moate
# 886007  Province of Leinster  County Westmeath             Moate
# 886008  Province of Leinster  County Westmeath             Moate
#
#                                                   address   latitude  \
# 478379  Penarrow Road Mylor Yacht Harbour, Mylor Churc...  50.177025
# 478380       39 Old Woking Road, Byfleet KT14 6LG England  51.337010
# 478381         Coldharbour Road, Byfleet GU22 8SW England  51.327370
# 478382             23 High Road, Byfleet KT14 7QH England  51.339140
# 478383     72 High Road Byfleet, Byfleet KT14 7QL England  51.338920
# ...                                                   ...        ...
# 886004                        Mount Temple, Moate Ireland  53.427540
# 886005                       Church Street, Moate Ireland  53.396410
# 886006                Main Street, Moate N37 XE93 Ireland  53.395520
# 886007                       Church Street, Moate Ireland  53.395832
# 886008                         Main Street, Moate Ireland  53.395930
#
#         longitude price_level price_range                           cuisines  \
# 478379  -5.053397      €€-€€€      €5-€17                      Cafe, British
# 478380  -0.504781           €         NaN                               Deli
# 478381  -0.510920         NaN         NaN                      International
# 478382  -0.478110      €€-€€€      €6-€11         Indian, Asian, Bangladeshi
# 478383  -0.476430      €€-€€€         NaN                            Chinese
# ...           ...         ...         ...                                ...
# 886004  -7.773970      €€-€€€         NaN                    Irish, European
# 886005  -7.724860           €         NaN                               Cafe
# 886006  -7.720757           €      €4-€10  American, Irish, Pizza, Fast food
# 886007  -7.725000      €€-€€€         NaN       Irish, European, Soups, Cafe
# 886008  -7.721720           €         NaN                           Pub, Bar
#
#         avg_rating  total_reviews_count default_language
# 478379         4.5                347.0          English
# 478380         3.5                  4.0          English
# 478381         5.0                  6.0          English
# 478382         3.0                  4.0          English
# 478383         2.5                 10.0          English
# ...            ...                  ...              ...
# 886004         4.5                104.0          English
# 886005         5.0                  8.0          English
# 886006         4.5                 11.0          English
# 886007         4.5                106.0          English
# 886008         5.0                 23.0          English
#
# [179233 rows x 15 columns]

# %%
location_explore_df = euro_resto_clean.loc[(euro_resto_clean['latitude'] == 47.83) &
                                           (euro_resto_clean['longitude'] == 13.00) ]
location_explore_df
# Out:
# Empty DataFrame
# Columns: [restaurant_link, restaurant_name, country, region, province, city, address, latitude, longitude, price_level, price_range, cuisines, avg_rating, total_reviews_count, default_language]
# Index: []

# %%
midsummer_df = euro_resto_clean.loc[(euro_resto_clean['restaurant_name'] == "Amador")]
midsummer_df
# Out:
#           restaurant_link restaurant_name  country             region  \
# 308217  g190454-d10147252          Amador  Austria      Vienna Region
# 324170  g1047911-d4752819          Amador    Spain  Valencian Country
#
#                     province    city  \
# 308217                   NaN  Vienna
# 324170  Province of Alicante     NaN
#
#                                                address  latitude  longitude  \
# 308217      Grinzinger Strasse 86, Vienna 1190 Austria  48.25391  16.358658
# 324170  Calle colonizacion, Pilar de la Horadada Spain  37.86996  -0.798050
#
#        price_level price_range                          cuisines  avg_rating  \
# 308217        €€€€    €89-€265                          European         4.5
# 324170      €€-€€€         NaN  Mediterranean, European, Spanish         4.5
#
#         total_reviews_count default_language
# 308217                 72.0          English
# 324170                 36.0          English

# %%
cost = euro_resto_clean['price_level'].unique()
cost
# Out:
# array(['€', '€€-€€€', nan, '€€€€'], dtype=object)

# %%
euro_resto_clean['price_level'].notnull().count()
# Out:
# 1083397

# %%
britain_df.dtypes
# Out:
# restaurant_link         object
# restaurant_name         object
# country                 object
# region                  object
# province                object
# city                    object
# address                 object
# latitude               float64
# longitude              float64
# price_level             object
# price_range             object
# cuisines                object
# avg_rating             float64
# total_reviews_count    float64
# default_language        object
# dtype: object
