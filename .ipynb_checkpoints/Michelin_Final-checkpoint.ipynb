# %% [markdown]
# # Exploratory Michelin Star

# %%
#import the dependencies
import pandas as pd

# %%
#create a list of files --> will be used in the loop to import
file_names = ["../michelin/one-star-michelin-restaurants.csv",
              "../michelin/two-stars-michelin-restaurants.csv",
              "../michelin/three-stars-michelin-restaurants.csv"]

# "../michelin/two-stars-michelin-restaurants.csv"
# "../michelin/three-stars-michelin-restaurants.csv"

# %%
#create an empty DF that will eventually hold the 3 files (perm-DF)
michelin_df = pd.DataFrame()
michelin_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#import the data
#for loop to cycle through each file

for i in file_names:
    #import the data
    michelin_data = pd.read_csv(i)
    
    #clear the temp df
    temp_df = pd.DataFrame()
    
    #add file to DF
    temp_df = pd.DataFrame(michelin_data)
    
    #create a column to add the # of stars
    temp_df['stars'] = (file_names.index(i)+1)
        
    #append temp df to michelin_df
    michelin_df = michelin_df.append(temp_df, ignore_index=True)
# michelin_df.head()
michelin_df = michelin_df.drop(['url'], axis=1)

# %%
michelin_df['region'].unique().tolist()
# Out:
# ['Austria',
#  'California',
#  'Chicago',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Finland',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'Macau',
#  'Norway',
#  'New York City',
#  'Poland',
#  'Ireland',
#  'Rio de Janeiro',
#  'Sao Paulo',
#  'South Korea',
#  'Singapore',
#  'Sweden',
#  'Taipei',
#  'Thailand',
#  'Washington DC',
#  'United Kingdom']

# %%
#filter the dataset to only include The british Island countries
michelin_df = michelin_df.loc[(michelin_df['region'] == "United Kingdom")| 
                                    (michelin_df['region'] == "Ireland")]

# %%
michelin_df.head()
# michelin_df.dtypes
# Out:
#                name  year   latitude  longitude  \
# 261           Aniar  2019  53.271120  -9.057078
# 262            Loam  2019  53.273840  -9.044447
# 263  Wild Honey Inn  2019  53.031510  -9.291100
# 264        Chestnut  2019  51.562588  -9.460854
# 265            Mews  2019  51.482850  -9.372340
#
#                                city   region zipCode          cuisine price  \
# 261                 Gaillimh/Galway  Ireland     NaN         Creative   NaN
# 262                 Gaillimh/Galway  Ireland     NaN         Creative   NaN
# 263  Lios Dúin Bhearna/Lisdoonvarna  Ireland     NaN  Classic cuisine   NaN
# 264                      Ballydehob  Ireland     NaN   Modern cuisine   NaN
# 265                       Baltimore  Ireland     NaN   Modern cuisine   NaN
#
#      stars
# 261      1
# 262      1
# 263      1
# 264      1
# 265      1

# %%
#truncate latitude to n decimal places
lat_list = michelin_df['latitude'].tolist()

lat_list_trunc = []

for x in lat_list:
    n=3
    multiplier = 10**n
    value = int(x*(10**n))
    lat_list_trunc.append(value)

michelin_df['lat_trunc'] = lat_list_trunc

# %%
#truncate longitude to n decimal places
long_list = michelin_df['longitude'].tolist()

long_list_trunc = []

for x in long_list:
    n=3
    multiplier = 10**n
    value = int(x*(10**n))
    long_list_trunc.append(value)

michelin_df['long_trunc'] = long_list_trunc

# %%
#create a location key

michelin_df['lat_trunc']=michelin_df['lat_trunc'].astype(str)
michelin_df['long_trunc']=michelin_df['long_trunc'].astype(str)
michelin_df['location_key'] = michelin_df[['lat_trunc', 'long_trunc']].agg('_'.join, axis=1)

# %%
#remove string words
words_to_remove = ['Restaurant', 'restaurant', 'The', 'the', 'bar', 'Bar', 'Inn']

for word in words_to_remove:
    michelin_df['restaurant_name_clean'] = michelin_df['name'].str.replace(word,"")

# %%
michelin_df.tail(10)
# Out:
#                                     name  year   latitude  longitude  \
# 654          Dinner by Heston Blumenthal  2019  51.502080  -0.160110
# 655                                  Umu  2019  51.511300  -0.144550
# 656  Sketch (The Lecture Room & Library)  2019  51.512870  -0.141360
# 657                           Greenhouse  2019  51.507690  -0.149260
# 658              Claude Bosi at Bibendum  2019  51.493410  -0.169089
# 690                             Fat Duck  2019  51.508280  -0.702320
# 691                        Waterside Inn  2019  51.507730  -0.701210
# 692      Alain Ducasse at The Dorchester  2019  51.507120  -0.152520
# 693                            The Araki  2019  51.511826  -0.140389
# 694                        Gordon Ramsay  2019  51.485460  -0.162020
#
#           city          region   zipCode              cuisine price  stars  \
# 654  Hyde Park  United Kingdom  SW1X 7LA  Traditional British   NaN      2
# 655    Mayfair  United Kingdom   W1J 6LX             Japanese   NaN      2
# 656    Mayfair  United Kingdom   W1S 2XG        Modern French   NaN      2
# 657    Mayfair  United Kingdom   W1J 5NY             Creative   NaN      2
# 658    Chelsea  United Kingdom   SW3 6RD               French   NaN      2
# 690       Bray  United Kingdom   SL6 2AQ             Creative   NaN      3
# 691       Bray  United Kingdom   SL6 2AT       Classic French   NaN      3
# 692    Mayfair  United Kingdom   W1K 1QA               French   NaN      3
# 693    Mayfair  United Kingdom   W1S 3BF             Japanese   NaN      3
# 694    Chelsea  United Kingdom   SW3 4HP               French   NaN      3
#
#     lat_trunc long_trunc location_key                restaurant_name_clean
# 654     51502       -160   51502_-160          Dinner by Heston Blumenthal
# 655     51511       -144   51511_-144                                  Umu
# 656     51512       -141   51512_-141  Sketch (The Lecture Room & Library)
# 657     51507       -149   51507_-149                           Greenhouse
# 658     51493       -169   51493_-169              Claude Bosi at Bibendum
# 690     51508       -702   51508_-702                             Fat Duck
# 691     51507       -701   51507_-701                           Waterside
# 692     51507       -152   51507_-152      Alain Ducasse at The Dorchester
# 693     51511       -140   51511_-140                            The Araki
# 694     51485       -162   51485_-162                        Gordon Ramsay

# %%
#export the data
michelin_df.to_csv('Resources/michelin_data.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-19-fa7c83775324> in <module>
#       1 #export the data
# ----> 2 michelin_df.to_csv('Resources/michelin_data.csv')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# PermissionError: [Errno 13] Permission denied: 'Resources/michelin_data.csv'
